# %%
import os
import sys

sys.path.append(os.pardir)

import numpy as np
import matplotlib.pyplot as plt

from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

x_train = x_train[:300]
t_train = t_train[:300]

weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)
optimizer = SGD(lr=0.01)

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.07666666666666666, test acc:0.0906
# epoch:1, train acc:0.08, test acc:0.0905
# epoch:2, train acc:0.10333333333333333, test acc:0.1026
# epoch:3, train acc:0.17, test acc:0.1259
# epoch:4, train acc:0.25333333333333335, test acc:0.1651
# epoch:5, train acc:0.3, test acc:0.195
# epoch:6, train acc:0.37333333333333335, test acc:0.2185
# epoch:7, train acc:0.43, test acc:0.2553
# epoch:8, train acc:0.43666666666666665, test acc:0.2845
# epoch:9, train acc:0.44333333333333336, test acc:0.3008
# epoch:10, train acc:0.48, test acc:0.3136
# epoch:11, train acc:0.5033333333333333, test acc:0.3277
# epoch:12, train acc:0.5166666666666667, test acc:0.3469
# epoch:13, train acc:0.54, test acc:0.3674
# epoch:14, train acc:0.54, test acc:0.3764
# epoch:15, train acc:0.5966666666666667, test acc:0.4091
# epoch:16, train acc:0.6033333333333334, test acc:0.4217
# epoch:17, train acc:0.6166666666666667, test acc:0.4368
# epoch:18, train acc:0.6233333333333333, test acc:0.4512
# epoch:19, train acc:0.6333333333333333, test acc:0.4594
# epoch:20, train acc:0.65, test acc:0.469
# epoch:21, train acc:0.66, test acc:0.4803
# epoch:22, train acc:0.69, test acc:0.4978
# epoch:23, train acc:0.6933333333333334, test acc:0.5013
# epoch:24, train acc:0.71, test acc:0.5124
# epoch:25, train acc:0.7233333333333334, test acc:0.5204
# epoch:26, train acc:0.74, test acc:0.5276
# epoch:27, train acc:0.77, test acc:0.5347
# epoch:28, train acc:0.7833333333333333, test acc:0.5483
# epoch:29, train acc:0.78, test acc:0.5488
# epoch:30, train acc:0.79, test acc:0.5602
# epoch:31, train acc:0.8, test acc:0.5633
# epoch:32, train acc:0.79, test acc:0.58
# epoch:33, train acc:0.8033333333333333, test acc:0.5808
# epoch:34, train acc:0.8033333333333333, test acc:0.5742
# epoch:35, train acc:0.8133333333333334, test acc:0.5937
# epoch:36, train acc:0.8166666666666667, test acc:0.5978
# epoch:37, train acc:0.83, test acc:0.5953
# epoch:38, train acc:0.8333333333333334, test acc:0.6137
# epoch:39, train acc:0.8366666666666667, test acc:0.616
# epoch:40, train acc:0.84, test acc:0.6197
# epoch:41, train acc:0.8733333333333333, test acc:0.6278
# epoch:42, train acc:0.8566666666666667, test acc:0.6353
# epoch:43, train acc:0.8766666666666667, test acc:0.6386
# epoch:44, train acc:0.8766666666666667, test acc:0.6345
# epoch:45, train acc:0.8533333333333334, test acc:0.6446
# epoch:46, train acc:0.89, test acc:0.6462
# epoch:47, train acc:0.9066666666666666, test acc:0.6478
# epoch:48, train acc:0.9066666666666666, test acc:0.6567
# epoch:49, train acc:0.9033333333333333, test acc:0.6468
# epoch:50, train acc:0.92, test acc:0.6647
# epoch:51, train acc:0.91, test acc:0.6442
# epoch:52, train acc:0.93, test acc:0.656
# epoch:53, train acc:0.9266666666666666, test acc:0.6686
# epoch:54, train acc:0.9366666666666666, test acc:0.6662
# epoch:55, train acc:0.94, test acc:0.6676
# epoch:56, train acc:0.92, test acc:0.6748
# epoch:57, train acc:0.9366666666666666, test acc:0.6801
# epoch:58, train acc:0.95, test acc:0.6736
# epoch:59, train acc:0.9433333333333334, test acc:0.679
# epoch:60, train acc:0.9533333333333334, test acc:0.6888
# epoch:61, train acc:0.9333333333333333, test acc:0.6809
# epoch:62, train acc:0.9533333333333334, test acc:0.6823
# epoch:63, train acc:0.95, test acc:0.6867
# epoch:64, train acc:0.9566666666666667, test acc:0.6845
# epoch:65, train acc:0.96, test acc:0.681
# epoch:66, train acc:0.96, test acc:0.6754
# epoch:67, train acc:0.96, test acc:0.6898
# epoch:68, train acc:0.9633333333333334, test acc:0.6901
# epoch:69, train acc:0.96, test acc:0.6936
# epoch:70, train acc:0.97, test acc:0.6832
# epoch:71, train acc:0.97, test acc:0.6953
# epoch:72, train acc:0.97, test acc:0.6937
# epoch:73, train acc:0.97, test acc:0.6977
# epoch:74, train acc:0.9733333333333334, test acc:0.6935
# epoch:75, train acc:0.9733333333333334, test acc:0.6933
# epoch:76, train acc:0.97, test acc:0.6926
# epoch:77, train acc:0.9766666666666667, test acc:0.6984
# epoch:78, train acc:0.9733333333333334, test acc:0.6951
# epoch:79, train acc:0.9733333333333334, test acc:0.7053
# epoch:80, train acc:0.9733333333333334, test acc:0.7014
# epoch:81, train acc:0.9766666666666667, test acc:0.6963
# epoch:82, train acc:0.98, test acc:0.694
# epoch:83, train acc:0.98, test acc:0.7009
# epoch:84, train acc:0.9833333333333333, test acc:0.7045
# epoch:85, train acc:0.9833333333333333, test acc:0.7072
# epoch:86, train acc:0.98, test acc:0.7032
# epoch:87, train acc:0.9833333333333333, test acc:0.7089
# epoch:88, train acc:0.9833333333333333, test acc:0.7069
# epoch:89, train acc:0.9833333333333333, test acc:0.7032
# epoch:90, train acc:0.98, test acc:0.7092
# epoch:91, train acc:0.9833333333333333, test acc:0.7131
# epoch:92, train acc:0.9866666666666667, test acc:0.7133
# epoch:93, train acc:0.9866666666666667, test acc:0.7133
# epoch:94, train acc:0.9833333333333333, test acc:0.7119
# epoch:95, train acc:0.9866666666666667, test acc:0.7113
# epoch:96, train acc:0.9833333333333333, test acc:0.7144
# epoch:97, train acc:0.9833333333333333, test acc:0.7145
# epoch:98, train acc:0.9866666666666667, test acc:0.7136
# epoch:99, train acc:0.9833333333333333, test acc:0.7139
# epoch:100, train acc:0.9866666666666667, test acc:0.7142
# epoch:101, train acc:0.98, test acc:0.7153
# epoch:102, train acc:0.99, test acc:0.7135
# epoch:103, train acc:0.99, test acc:0.711
# epoch:104, train acc:0.9833333333333333, test acc:0.7164
# epoch:105, train acc:0.99, test acc:0.7189
# epoch:106, train acc:0.9833333333333333, test acc:0.7197
# epoch:107, train acc:0.9866666666666667, test acc:0.7112
# epoch:108, train acc:0.99, test acc:0.7189
# epoch:109, train acc:0.99, test acc:0.7216
# epoch:110, train acc:0.99, test acc:0.7227
# epoch:111, train acc:0.9866666666666667, test acc:0.7183
# epoch:112, train acc:0.99, test acc:0.7194
# epoch:113, train acc:0.99, test acc:0.7206
# epoch:114, train acc:0.99, test acc:0.723
# epoch:115, train acc:0.99, test acc:0.7206
# epoch:116, train acc:0.9933333333333333, test acc:0.7216
# epoch:117, train acc:0.9933333333333333, test acc:0.7227
# epoch:118, train acc:0.99, test acc:0.7206
# epoch:119, train acc:0.9933333333333333, test acc:0.7208
# epoch:120, train acc:0.99, test acc:0.7223
# epoch:121, train acc:0.9933333333333333, test acc:0.72
# epoch:122, train acc:0.9933333333333333, test acc:0.7188
# epoch:123, train acc:0.9933333333333333, test acc:0.7198
# epoch:124, train acc:0.9966666666666667, test acc:0.7278
# epoch:125, train acc:0.9966666666666667, test acc:0.7239
# epoch:126, train acc:1.0, test acc:0.7246
# epoch:127, train acc:1.0, test acc:0.7256
# epoch:128, train acc:1.0, test acc:0.7273
# epoch:129, train acc:1.0, test acc:0.7267
# epoch:130, train acc:1.0, test acc:0.7245
# epoch:131, train acc:0.9966666666666667, test acc:0.7225
# epoch:132, train acc:1.0, test acc:0.7287
# epoch:133, train acc:1.0, test acc:0.7272
# epoch:134, train acc:1.0, test acc:0.7254
# epoch:135, train acc:1.0, test acc:0.7245
# epoch:136, train acc:1.0, test acc:0.7251
# epoch:137, train acc:1.0, test acc:0.7281
# epoch:138, train acc:1.0, test acc:0.7306
# epoch:139, train acc:1.0, test acc:0.7266
# epoch:140, train acc:1.0, test acc:0.7279
# epoch:141, train acc:1.0, test acc:0.7262
# epoch:142, train acc:1.0, test acc:0.7281
# epoch:143, train acc:1.0, test acc:0.7262
# epoch:144, train acc:1.0, test acc:0.7244
# epoch:145, train acc:1.0, test acc:0.7283
# epoch:146, train acc:1.0, test acc:0.7265
# epoch:147, train acc:1.0, test acc:0.7268
# epoch:148, train acc:1.0, test acc:0.7288
# epoch:149, train acc:1.0, test acc:0.7274
# epoch:150, train acc:1.0, test acc:0.7269
# epoch:151, train acc:1.0, test acc:0.7314
# epoch:152, train acc:1.0, test acc:0.7278
# epoch:153, train acc:1.0, test acc:0.7332
# epoch:154, train acc:1.0, test acc:0.73
# epoch:155, train acc:1.0, test acc:0.7312
# epoch:156, train acc:1.0, test acc:0.7312
# epoch:157, train acc:1.0, test acc:0.7287
# epoch:158, train acc:1.0, test acc:0.7312
# epoch:159, train acc:1.0, test acc:0.7312
# epoch:160, train acc:1.0, test acc:0.73
# epoch:161, train acc:1.0, test acc:0.7264
# epoch:162, train acc:1.0, test acc:0.7296
# epoch:163, train acc:1.0, test acc:0.7308
# epoch:164, train acc:1.0, test acc:0.7306
# epoch:165, train acc:1.0, test acc:0.7302
# epoch:166, train acc:1.0, test acc:0.7327
# epoch:167, train acc:1.0, test acc:0.7294
# epoch:168, train acc:1.0, test acc:0.7315
# epoch:169, train acc:1.0, test acc:0.7322
# epoch:170, train acc:1.0, test acc:0.7328
# epoch:171, train acc:1.0, test acc:0.733
# epoch:172, train acc:1.0, test acc:0.7331
# epoch:173, train acc:1.0, test acc:0.7333
# epoch:174, train acc:1.0, test acc:0.7338
# epoch:175, train acc:1.0, test acc:0.733
# epoch:176, train acc:1.0, test acc:0.7347
# epoch:177, train acc:1.0, test acc:0.7338
# epoch:178, train acc:1.0, test acc:0.7333
# epoch:179, train acc:1.0, test acc:0.7332
# epoch:180, train acc:1.0, test acc:0.7325
# epoch:181, train acc:1.0, test acc:0.7309
# epoch:182, train acc:1.0, test acc:0.7324
# epoch:183, train acc:1.0, test acc:0.7325
# epoch:184, train acc:1.0, test acc:0.7327
# epoch:185, train acc:1.0, test acc:0.7345
# epoch:186, train acc:1.0, test acc:0.7334
# epoch:187, train acc:1.0, test acc:0.7322
# epoch:188, train acc:1.0, test acc:0.734
# epoch:189, train acc:1.0, test acc:0.7352
# epoch:190, train acc:1.0, test acc:0.7349
# epoch:191, train acc:1.0, test acc:0.7352
# epoch:192, train acc:1.0, test acc:0.7327
# epoch:193, train acc:1.0, test acc:0.736
# epoch:194, train acc:1.0, test acc:0.7353
# epoch:195, train acc:1.0, test acc:0.7359
# epoch:196, train acc:1.0, test acc:0.7356
# epoch:197, train acc:1.0, test acc:0.7359
# epoch:198, train acc:1.0, test acc:0.7343
# epoch:199, train acc:1.0, test acc:0.7362
# epoch:200, train acc:1.0, test acc:0.7345

# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

x_train = x_train[:300]
t_train = t_train[:300]

weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01)

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.11333333333333333, test acc:0.1015
# epoch:1, train acc:0.11666666666666667, test acc:0.1107
# epoch:2, train acc:0.13333333333333333, test acc:0.1232
# epoch:3, train acc:0.14333333333333334, test acc:0.1315
# epoch:4, train acc:0.16666666666666666, test acc:0.1448
# epoch:5, train acc:0.19666666666666666, test acc:0.16
# epoch:6, train acc:0.21666666666666667, test acc:0.1661
# epoch:7, train acc:0.25333333333333335, test acc:0.1853
# epoch:8, train acc:0.2833333333333333, test acc:0.1927
# epoch:9, train acc:0.28, test acc:0.1976
# epoch:10, train acc:0.31666666666666665, test acc:0.221
# epoch:11, train acc:0.3433333333333333, test acc:0.2342
# epoch:12, train acc:0.3433333333333333, test acc:0.2357
# epoch:13, train acc:0.37333333333333335, test acc:0.2569
# epoch:14, train acc:0.39666666666666667, test acc:0.2714
# epoch:15, train acc:0.3933333333333333, test acc:0.282
# epoch:16, train acc:0.4066666666666667, test acc:0.2939
# epoch:17, train acc:0.42, test acc:0.2995
# epoch:18, train acc:0.4166666666666667, test acc:0.2959
# epoch:19, train acc:0.4166666666666667, test acc:0.3107
# epoch:20, train acc:0.4666666666666667, test acc:0.3306
# epoch:21, train acc:0.48, test acc:0.3463
# epoch:22, train acc:0.49666666666666665, test acc:0.3632
# epoch:23, train acc:0.52, test acc:0.3871
# epoch:24, train acc:0.5366666666666666, test acc:0.3936
# epoch:25, train acc:0.5466666666666666, test acc:0.4067
# epoch:26, train acc:0.56, test acc:0.4259
# epoch:27, train acc:0.5833333333333334, test acc:0.4366
# epoch:28, train acc:0.5766666666666667, test acc:0.4341
# epoch:29, train acc:0.5866666666666667, test acc:0.4455
# epoch:30, train acc:0.62, test acc:0.4628
# epoch:31, train acc:0.6433333333333333, test acc:0.4855
# epoch:32, train acc:0.64, test acc:0.4929
# epoch:33, train acc:0.6566666666666666, test acc:0.5051
# epoch:34, train acc:0.6366666666666667, test acc:0.5065
# epoch:35, train acc:0.6233333333333333, test acc:0.5105
# epoch:36, train acc:0.6566666666666666, test acc:0.5165
# epoch:37, train acc:0.6466666666666666, test acc:0.5091
# epoch:38, train acc:0.67, test acc:0.5369
# epoch:39, train acc:0.67, test acc:0.5323
# epoch:40, train acc:0.6766666666666666, test acc:0.545
# epoch:41, train acc:0.7033333333333334, test acc:0.5499
# epoch:42, train acc:0.7033333333333334, test acc:0.5633
# epoch:43, train acc:0.71, test acc:0.5679
# epoch:44, train acc:0.72, test acc:0.5653
# epoch:45, train acc:0.72, test acc:0.5722
# epoch:46, train acc:0.7233333333333334, test acc:0.5886
# epoch:47, train acc:0.7233333333333334, test acc:0.5804
# epoch:48, train acc:0.7266666666666667, test acc:0.585
# epoch:49, train acc:0.73, test acc:0.5817
# epoch:50, train acc:0.7333333333333333, test acc:0.5845
# epoch:51, train acc:0.7333333333333333, test acc:0.5859
# epoch:52, train acc:0.7333333333333333, test acc:0.5802
# epoch:53, train acc:0.73, test acc:0.5967
# epoch:54, train acc:0.7533333333333333, test acc:0.6037
# epoch:55, train acc:0.75, test acc:0.6068
# epoch:56, train acc:0.7533333333333333, test acc:0.5945
# epoch:57, train acc:0.74, test acc:0.6049
# epoch:58, train acc:0.77, test acc:0.6182
# epoch:59, train acc:0.76, test acc:0.6085
# epoch:60, train acc:0.7766666666666666, test acc:0.6166
# epoch:61, train acc:0.7766666666666666, test acc:0.6121
# epoch:62, train acc:0.77, test acc:0.6131
# epoch:63, train acc:0.7833333333333333, test acc:0.6257
# epoch:64, train acc:0.7966666666666666, test acc:0.6206
# epoch:65, train acc:0.7866666666666666, test acc:0.643
# epoch:66, train acc:0.81, test acc:0.6512
# epoch:67, train acc:0.8, test acc:0.638
# epoch:68, train acc:0.79, test acc:0.6219
# epoch:69, train acc:0.7766666666666666, test acc:0.6122
# epoch:70, train acc:0.7866666666666666, test acc:0.6288
# epoch:71, train acc:0.81, test acc:0.6225
# epoch:72, train acc:0.82, test acc:0.6367
# epoch:73, train acc:0.8166666666666667, test acc:0.6467
# epoch:74, train acc:0.8233333333333334, test acc:0.6525
# epoch:75, train acc:0.8033333333333333, test acc:0.6424
# epoch:76, train acc:0.8133333333333334, test acc:0.64
# epoch:77, train acc:0.8166666666666667, test acc:0.6553
# epoch:78, train acc:0.8366666666666667, test acc:0.6662
# epoch:79, train acc:0.8133333333333334, test acc:0.6567
# epoch:80, train acc:0.8133333333333334, test acc:0.6556
# epoch:81, train acc:0.8233333333333334, test acc:0.6731
# epoch:82, train acc:0.82, test acc:0.6689
# epoch:83, train acc:0.8266666666666667, test acc:0.6774
# epoch:84, train acc:0.82, test acc:0.6489
# epoch:85, train acc:0.83, test acc:0.6663
# epoch:86, train acc:0.8233333333333334, test acc:0.6674
# epoch:87, train acc:0.83, test acc:0.6619
# epoch:88, train acc:0.8366666666666667, test acc:0.6715
# epoch:89, train acc:0.84, test acc:0.6829
# epoch:90, train acc:0.8566666666666667, test acc:0.6759
# epoch:91, train acc:0.8566666666666667, test acc:0.6877
# epoch:92, train acc:0.8533333333333334, test acc:0.6957
# epoch:93, train acc:0.85, test acc:0.681
# epoch:94, train acc:0.8433333333333334, test acc:0.687
# epoch:95, train acc:0.8433333333333334, test acc:0.6847
# epoch:96, train acc:0.8466666666666667, test acc:0.6978
# epoch:97, train acc:0.8366666666666667, test acc:0.6902
# epoch:98, train acc:0.8333333333333334, test acc:0.6674
# epoch:99, train acc:0.8366666666666667, test acc:0.6753
# epoch:100, train acc:0.85, test acc:0.691
# epoch:101, train acc:0.8533333333333334, test acc:0.6898
# epoch:102, train acc:0.8333333333333334, test acc:0.6814
# epoch:103, train acc:0.8233333333333334, test acc:0.6897
# epoch:104, train acc:0.8366666666666667, test acc:0.6872
# epoch:105, train acc:0.85, test acc:0.6962
# epoch:106, train acc:0.8466666666666667, test acc:0.6872
# epoch:107, train acc:0.8733333333333333, test acc:0.699
# epoch:108, train acc:0.8733333333333333, test acc:0.7006
# epoch:109, train acc:0.8633333333333333, test acc:0.7022
# epoch:110, train acc:0.85, test acc:0.6905
# epoch:111, train acc:0.8633333333333333, test acc:0.6842
# epoch:112, train acc:0.8633333333333333, test acc:0.6851
# epoch:113, train acc:0.8733333333333333, test acc:0.7054
# epoch:114, train acc:0.8733333333333333, test acc:0.7037
# epoch:115, train acc:0.87, test acc:0.6934
# epoch:116, train acc:0.85, test acc:0.6936
# epoch:117, train acc:0.8533333333333334, test acc:0.689
# epoch:118, train acc:0.87, test acc:0.6935
# epoch:119, train acc:0.8733333333333333, test acc:0.7087
# epoch:120, train acc:0.87, test acc:0.7074
# epoch:121, train acc:0.8533333333333334, test acc:0.6964
# epoch:122, train acc:0.88, test acc:0.7044
# epoch:123, train acc:0.8733333333333333, test acc:0.7056
# epoch:124, train acc:0.8533333333333334, test acc:0.6981
# epoch:125, train acc:0.88, test acc:0.7123
# epoch:126, train acc:0.8733333333333333, test acc:0.7053
# epoch:127, train acc:0.8866666666666667, test acc:0.7092
# epoch:128, train acc:0.8633333333333333, test acc:0.7115
# epoch:129, train acc:0.87, test acc:0.7075
# epoch:130, train acc:0.89, test acc:0.7093
# epoch:131, train acc:0.89, test acc:0.7063
# epoch:132, train acc:0.8866666666666667, test acc:0.7152
# epoch:133, train acc:0.88, test acc:0.7027
# epoch:134, train acc:0.87, test acc:0.6937
# epoch:135, train acc:0.8733333333333333, test acc:0.7018
# epoch:136, train acc:0.8833333333333333, test acc:0.7042
# epoch:137, train acc:0.8766666666666667, test acc:0.7127
# epoch:138, train acc:0.8933333333333333, test acc:0.7089
# epoch:139, train acc:0.89, test acc:0.7152
# epoch:140, train acc:0.8833333333333333, test acc:0.7184
# epoch:141, train acc:0.88, test acc:0.7077
# epoch:142, train acc:0.89, test acc:0.7219
# epoch:143, train acc:0.9, test acc:0.7133
# epoch:144, train acc:0.8833333333333333, test acc:0.7062
# epoch:145, train acc:0.8933333333333333, test acc:0.7187
# epoch:146, train acc:0.8866666666666667, test acc:0.7116
# epoch:147, train acc:0.88, test acc:0.7017
# epoch:148, train acc:0.8733333333333333, test acc:0.7037
# epoch:149, train acc:0.9, test acc:0.7231
# epoch:150, train acc:0.89, test acc:0.7197
# epoch:151, train acc:0.8866666666666667, test acc:0.7143
# epoch:152, train acc:0.89, test acc:0.7089
# epoch:153, train acc:0.8866666666666667, test acc:0.7229
# epoch:154, train acc:0.8933333333333333, test acc:0.7199
# epoch:155, train acc:0.8833333333333333, test acc:0.7118
# epoch:156, train acc:0.89, test acc:0.7165
# epoch:157, train acc:0.8966666666666666, test acc:0.7036
# epoch:158, train acc:0.8933333333333333, test acc:0.7061
# epoch:159, train acc:0.8966666666666666, test acc:0.7119
# epoch:160, train acc:0.8966666666666666, test acc:0.7086
# epoch:161, train acc:0.8866666666666667, test acc:0.7052
# epoch:162, train acc:0.8933333333333333, test acc:0.7085
# epoch:163, train acc:0.9, test acc:0.7096
# epoch:164, train acc:0.9033333333333333, test acc:0.7099
# epoch:165, train acc:0.89, test acc:0.7081
# epoch:166, train acc:0.8833333333333333, test acc:0.7121
# epoch:167, train acc:0.9066666666666666, test acc:0.715
# epoch:168, train acc:0.8866666666666667, test acc:0.7153
# epoch:169, train acc:0.89, test acc:0.7043
# epoch:170, train acc:0.8866666666666667, test acc:0.7138
# epoch:171, train acc:0.8966666666666666, test acc:0.718
# epoch:172, train acc:0.9033333333333333, test acc:0.7136
# epoch:173, train acc:0.8933333333333333, test acc:0.7152
# epoch:174, train acc:0.9, test acc:0.7184
# epoch:175, train acc:0.9133333333333333, test acc:0.7277
# epoch:176, train acc:0.9066666666666666, test acc:0.7251
# epoch:177, train acc:0.9066666666666666, test acc:0.7199
# epoch:178, train acc:0.9, test acc:0.716
# epoch:179, train acc:0.9, test acc:0.7116
# epoch:180, train acc:0.9233333333333333, test acc:0.7195
# epoch:181, train acc:0.9033333333333333, test acc:0.719
# epoch:182, train acc:0.89, test acc:0.7156
# epoch:183, train acc:0.8966666666666666, test acc:0.7218
# epoch:184, train acc:0.9033333333333333, test acc:0.7228
# epoch:185, train acc:0.9, test acc:0.7198
# epoch:186, train acc:0.9033333333333333, test acc:0.7216
# epoch:187, train acc:0.8966666666666666, test acc:0.7204
# epoch:188, train acc:0.9066666666666666, test acc:0.7084
# epoch:189, train acc:0.9, test acc:0.7139
# epoch:190, train acc:0.8966666666666666, test acc:0.7202
# epoch:191, train acc:0.9066666666666666, test acc:0.7159
# epoch:192, train acc:0.9, test acc:0.7204
# epoch:193, train acc:0.9, test acc:0.7147
# epoch:194, train acc:0.9066666666666666, test acc:0.7128
# epoch:195, train acc:0.9133333333333333, test acc:0.7261
# epoch:196, train acc:0.9133333333333333, test acc:0.7244
# epoch:197, train acc:0.9166666666666666, test acc:0.7194
# epoch:198, train acc:0.9033333333333333, test acc:0.718
# epoch:199, train acc:0.9166666666666666, test acc:0.721
# epoch:200, train acc:0.8966666666666666, test acc:0.7217

# %%
# coding: utf-8
import os
import sys
sys.path.append(os.pardir)
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

x_train = x_train[:300]
t_train = t_train[:300]

use_dropout = True
dropout_ratio = 0.2
# ====================================================

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=301, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list

markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# train loss:2.3140196756880584
# === epoch:1, train acc:0.1, test acc:0.0926 ===
# train loss:2.2969908883485117
# train loss:2.308571844238221
# train loss:2.3066403218708307
# === epoch:2, train acc:0.11333333333333333, test acc:0.0941 ===
# train loss:2.3240604268481126
# train loss:2.3066630160872768
# train loss:2.293566513189338
# === epoch:3, train acc:0.12, test acc:0.096 ===
# train loss:2.3118967022398293
# train loss:2.3152136888953105
# train loss:2.313811138286174
# === epoch:4, train acc:0.12333333333333334, test acc:0.0982 ===
# train loss:2.3093728496093333
# train loss:2.295259717629035
# train loss:2.304402318975916
# === epoch:5, train acc:0.12, test acc:0.0999 ===
# train loss:2.305810263033163
# train loss:2.295500022483496
# train loss:2.290048836707124
# === epoch:6, train acc:0.12333333333333334, test acc:0.1036 ===
# train loss:2.3062693937313186
# train loss:2.2958921706344966
# train loss:2.3120500843175726
# === epoch:7, train acc:0.12333333333333334, test acc:0.1048 ===
# train loss:2.3044909029869887
# train loss:2.290567437329476
# train loss:2.310229174266517
# === epoch:8, train acc:0.12333333333333334, test acc:0.1085 ===
# train loss:2.2888451842797606
# train loss:2.2891044709889297
# train loss:2.313208261135606
# === epoch:9, train acc:0.12666666666666668, test acc:0.1132 ===
# train loss:2.311370246075272
# train loss:2.282516661524475
# train loss:2.301308129062237
# === epoch:10, train acc:0.13, test acc:0.1184 ===
# train loss:2.305296074638411
# train loss:2.2877006741703085
# train loss:2.2955325015696277
# === epoch:11, train acc:0.13, test acc:0.123 ===
# train loss:2.2988079405115114
# train loss:2.2926818870240506
# train loss:2.281388995642102
# === epoch:12, train acc:0.13333333333333333, test acc:0.1272 ===
# train loss:2.304737611847946
# train loss:2.303635973993633
# train loss:2.2808747142056816
# === epoch:13, train acc:0.14, test acc:0.1292 ===
# train loss:2.298325169587903
# train loss:2.308112046502248
# train loss:2.296693883856623
# === epoch:14, train acc:0.15, test acc:0.1345 ===
# train loss:2.2869298551207398
# train loss:2.2931202538584974
# train loss:2.278193201329094
# === epoch:15, train acc:0.15, test acc:0.1394 ===
# train loss:2.2828618884060328
# train loss:2.2942111674745056
# train loss:2.28944226941957
# === epoch:16, train acc:0.14666666666666667, test acc:0.1436 ===
# train loss:2.279917941514934
# train loss:2.2931207475634197
# train loss:2.2740338664532866
# === epoch:17, train acc:0.15666666666666668, test acc:0.1415 ===
# train loss:2.2853819434261466
# train loss:2.292202982132223
# train loss:2.2764838291831326
# === epoch:18, train acc:0.15333333333333332, test acc:0.1442 ===
# train loss:2.2643368723245008
# train loss:2.2805101526457285
# train loss:2.2976206180240895
# === epoch:19, train acc:0.16, test acc:0.1479 ===
# train loss:2.2856498063992468
# train loss:2.2855249696324123
# train loss:2.290252940901249
# === epoch:20, train acc:0.16, test acc:0.1528 ===
# train loss:2.2571568185032596
# train loss:2.288827809594957
# train loss:2.274717808939569
# === epoch:21, train acc:0.16, test acc:0.1565 ===
# train loss:2.275050769423799
# train loss:2.2765188659610036
# train loss:2.278829690459062
# === epoch:22, train acc:0.16, test acc:0.1536 ===
# train loss:2.2802768438314227
# train loss:2.2652289168926827
# train loss:2.2830906374234248
# === epoch:23, train acc:0.16333333333333333, test acc:0.1531 ===
# train loss:2.272161551971882
# train loss:2.263136793636752
# train loss:2.2569391812136814
# === epoch:24, train acc:0.16, test acc:0.1493 ===
# train loss:2.2712379416183426
# train loss:2.26755501528846
# train loss:2.2708920679347107
# === epoch:25, train acc:0.16666666666666666, test acc:0.1508 ===
# train loss:2.2805596780254045
# train loss:2.2749806117839704
# train loss:2.254432006077955
# === epoch:26, train acc:0.17666666666666667, test acc:0.1554 ===
# train loss:2.2615377186737784
# train loss:2.275082450389296
# train loss:2.2530197686010713
# === epoch:27, train acc:0.17666666666666667, test acc:0.1545 ===
# train loss:2.2702839792149074
# train loss:2.2374196615031945
# train loss:2.256357953818
# === epoch:28, train acc:0.17, test acc:0.1501 ===
# train loss:2.259386268103893
# train loss:2.2557369871397945
# train loss:2.2539424837692326
# === epoch:29, train acc:0.16, test acc:0.1465 ===
# train loss:2.2356032822761875
# train loss:2.246982931301363
# train loss:2.251199990552799
# === epoch:30, train acc:0.17333333333333334, test acc:0.1485 ===
# train loss:2.240719612938019
# train loss:2.2508935658470217
# train loss:2.2450337953969393
# === epoch:31, train acc:0.17333333333333334, test acc:0.1492 ===
# train loss:2.2515915683649994
# train loss:2.2529090539191796
# train loss:2.280708891512968
# === epoch:32, train acc:0.18333333333333332, test acc:0.1559 ===
# train loss:2.2591988465987027
# train loss:2.249378427655516
# train loss:2.282034973677151
# === epoch:33, train acc:0.18333333333333332, test acc:0.1565 ===
# train loss:2.2702279482813568
# train loss:2.251926880753481
# train loss:2.2574680983009268
# === epoch:34, train acc:0.18, test acc:0.1547 ===
# train loss:2.2515158419257997
# train loss:2.251427400188241
# train loss:2.267784413381055
# === epoch:35, train acc:0.18333333333333332, test acc:0.1573 ===
# train loss:2.252322014738486
# train loss:2.2650930557293627
# train loss:2.2211951608180653
# === epoch:36, train acc:0.18333333333333332, test acc:0.1601 ===
# train loss:2.2330516769137536
# train loss:2.2233582646755012
# train loss:2.2617005576275524
# === epoch:37, train acc:0.19, test acc:0.1614 ===
# train loss:2.250034544424115
# train loss:2.231672565398167
# train loss:2.2522369657519756
# === epoch:38, train acc:0.18333333333333332, test acc:0.1608 ===
# train loss:2.268980468744813
# train loss:2.2333779401118212
# train loss:2.2417949152597045
# === epoch:39, train acc:0.19, test acc:0.1612 ===
# train loss:2.2322608509847
# train loss:2.2523790842891827
# train loss:2.255636391785685
# === epoch:40, train acc:0.19333333333333333, test acc:0.1639 ===
# train loss:2.2166306685165655
# train loss:2.2592168839276745
# train loss:2.244367034353361
# === epoch:41, train acc:0.20666666666666667, test acc:0.167 ===
# train loss:2.248137602115955
# train loss:2.2408299825448648
# train loss:2.23749022026367
# === epoch:42, train acc:0.20666666666666667, test acc:0.1682 ===
# train loss:2.245725244553289
# train loss:2.219771569949674
# train loss:2.246840941052662
# === epoch:43, train acc:0.20666666666666667, test acc:0.1682 ===
# train loss:2.2356670022790133
# train loss:2.2166137318235517
# train loss:2.230096402628369
# === epoch:44, train acc:0.21333333333333335, test acc:0.1689 ===
# train loss:2.2278857443020126
# train loss:2.217209534162944
# train loss:2.2252136026916327
# === epoch:45, train acc:0.21, test acc:0.1691 ===
# train loss:2.247781566177684
# train loss:2.24601633326512
# train loss:2.2365262574937566
# === epoch:46, train acc:0.22, test acc:0.1732 ===
# train loss:2.2395440414282204
# train loss:2.2352276235656454
# train loss:2.229531387043348
# === epoch:47, train acc:0.23, test acc:0.1781 ===
# train loss:2.198687931432859
# train loss:2.245307173044475
# train loss:2.227708346860914
# === epoch:48, train acc:0.22333333333333333, test acc:0.1738 ===
# train loss:2.239517651201705
# train loss:2.2210143889855782
# train loss:2.225755492343174
# === epoch:49, train acc:0.22666666666666666, test acc:0.175 ===
# train loss:2.244137687696416
# train loss:2.1938870032095825
# train loss:2.229282720897676
# === epoch:50, train acc:0.22666666666666666, test acc:0.1773 ===
# train loss:2.235345871550873
# train loss:2.189936047664958
# train loss:2.2099348769733083
# === epoch:51, train acc:0.22666666666666666, test acc:0.1785 ===
# train loss:2.2314960009492286
# train loss:2.220129255119241
# train loss:2.195179223421263
# === epoch:52, train acc:0.22666666666666666, test acc:0.1795 ===
# train loss:2.196060114003011
# train loss:2.2011383234814046
# train loss:2.1665323952066875
# === epoch:53, train acc:0.21333333333333335, test acc:0.1718 ===
# train loss:2.2188884263216884
# train loss:2.2275428384575484
# train loss:2.2155623904878614
# === epoch:54, train acc:0.21333333333333335, test acc:0.1739 ===
# train loss:2.233400617067501
# train loss:2.2375890907314595
# train loss:2.2264324427742195
# === epoch:55, train acc:0.22666666666666666, test acc:0.1807 ===
# train loss:2.224067678404984
# train loss:2.227207398735474
# train loss:2.2277440581440806
# === epoch:56, train acc:0.23, test acc:0.1863 ===
# train loss:2.2076995435278737
# train loss:2.2065360667551768
# train loss:2.2108043210203117
# === epoch:57, train acc:0.23, test acc:0.192 ===
# train loss:2.1805438745588517
# train loss:2.199337929404617
# train loss:2.2172931026643825
# === epoch:58, train acc:0.22333333333333333, test acc:0.1946 ===
# train loss:2.1910738606603086
# train loss:2.2214179834459804
# train loss:2.188824993979131
# === epoch:59, train acc:0.21333333333333335, test acc:0.1908 ===
# train loss:2.1885396694483785
# train loss:2.1882817543382314
# train loss:2.2041097975668533
# === epoch:60, train acc:0.21333333333333335, test acc:0.1888 ===
# train loss:2.2208950689747096
# train loss:2.2106301068078333
# train loss:2.1673749899091437
# === epoch:61, train acc:0.21333333333333335, test acc:0.1908 ===
# train loss:2.1859922343236597
# train loss:2.2009717808581017
# train loss:2.218119006247853
# === epoch:62, train acc:0.21666666666666667, test acc:0.1911 ===
# train loss:2.2129032081882096
# train loss:2.176325233764119
# train loss:2.146776023699402
# === epoch:63, train acc:0.21666666666666667, test acc:0.1917 ===
# train loss:2.2292056705631746
# train loss:2.174829230597193
# train loss:2.1888475176850353
# === epoch:64, train acc:0.22, test acc:0.196 ===
# train loss:2.1474022165199984
# train loss:2.204412518642704
# train loss:2.1818894180702717
# === epoch:65, train acc:0.22, test acc:0.1957 ===
# train loss:2.2336132280397814
# train loss:2.205677055539372
# train loss:2.184773390460787
# === epoch:66, train acc:0.22, test acc:0.195 ===
# train loss:2.187932139781206
# train loss:2.1297546869121695
# train loss:2.189336553635384
# === epoch:67, train acc:0.22333333333333333, test acc:0.19 ===
# train loss:2.1189929153058755
# train loss:2.176533164389205
# train loss:2.2132054905858984
# === epoch:68, train acc:0.23, test acc:0.1988 ===
# train loss:2.1835589153957233
# train loss:2.1393373778199796
# train loss:2.12048039374631
# === epoch:69, train acc:0.24333333333333335, test acc:0.2043 ===
# train loss:2.2061702974091855
# train loss:2.162123834991771
# train loss:2.1858654758608465
# === epoch:70, train acc:0.24, test acc:0.1994 ===
# train loss:2.1670032360925293
# train loss:2.1556986001393152
# train loss:2.214926341561113
# === epoch:71, train acc:0.22666666666666666, test acc:0.1962 ===
# train loss:2.1602094737446986
# train loss:2.1383595846221426
# train loss:2.1130498963692137
# === epoch:72, train acc:0.23, test acc:0.1984 ===
# train loss:2.123811799871866
# train loss:2.1617097003084047
# train loss:2.1736233205972106
# === epoch:73, train acc:0.23333333333333334, test acc:0.2033 ===
# train loss:2.1541957400823146
# train loss:2.1808694440791565
# train loss:2.150144927304972
# === epoch:74, train acc:0.25, test acc:0.2082 ===
# train loss:2.197246497548084
# train loss:2.1366517307393216
# train loss:2.179040045284994
# === epoch:75, train acc:0.26, test acc:0.2114 ===
# train loss:2.1499109542377406
# train loss:2.1100265974562307
# train loss:2.14229166707123
# === epoch:76, train acc:0.26666666666666666, test acc:0.218 ===
# train loss:2.1078974864553794
# train loss:2.1593410877474724
# train loss:2.1498140747116845
# === epoch:77, train acc:0.2733333333333333, test acc:0.2265 ===
# train loss:2.105793993511827
# train loss:2.209013030376413
# train loss:2.1379804150729225
# === epoch:78, train acc:0.27666666666666667, test acc:0.2295 ===
# train loss:2.1859659435266026
# train loss:2.1164766028248714
# train loss:2.192050575768884
# === epoch:79, train acc:0.2733333333333333, test acc:0.237 ===
# train loss:2.118233927450224
# train loss:2.1478415404210716
# train loss:2.201998447140119
# === epoch:80, train acc:0.2833333333333333, test acc:0.2402 ===
# train loss:2.146665889171348
# train loss:2.1884957914976497
# train loss:2.1448762615570263
# === epoch:81, train acc:0.2833333333333333, test acc:0.2421 ===
# train loss:2.1657931180154297
# train loss:2.121892663022395
# train loss:2.1563425194955568
# === epoch:82, train acc:0.29333333333333333, test acc:0.2454 ===
# train loss:2.1100063394457886
# train loss:2.1267259152746854
# train loss:2.1411693241592538
# === epoch:83, train acc:0.29333333333333333, test acc:0.2448 ===
# train loss:2.17359935351457
# train loss:2.1204564630239586
# train loss:2.176879075298624
# === epoch:84, train acc:0.3, test acc:0.2469 ===
# train loss:2.131567666563711
# train loss:2.192296569534815
# train loss:2.119256344357238
# === epoch:85, train acc:0.30666666666666664, test acc:0.2521 ===
# train loss:2.0957708437873075
# train loss:2.1381185287542057
# train loss:2.1368824256067662
# === epoch:86, train acc:0.30666666666666664, test acc:0.2469 ===
# train loss:2.106680632240804
# train loss:2.104637240353496
# train loss:2.148040099012089
# === epoch:87, train acc:0.3, test acc:0.246 ===
# train loss:2.104397818458969
# train loss:2.1341328177775414
# train loss:2.134089824767176
# === epoch:88, train acc:0.30333333333333334, test acc:0.2508 ===
# train loss:2.1578331896278624
# train loss:2.108318030238992
# train loss:2.1573967049839227
# === epoch:89, train acc:0.31666666666666665, test acc:0.2557 ===
# train loss:2.1312414987523867
# train loss:2.0859154167222886
# train loss:2.1214746287863417
# === epoch:90, train acc:0.3233333333333333, test acc:0.2563 ===
# train loss:2.0945370312839473
# train loss:2.0919125580161504
# train loss:2.146882047400357
# === epoch:91, train acc:0.32, test acc:0.2549 ===
# train loss:2.15289373878506
# train loss:2.066215957330343
# train loss:2.1049555696257483
# === epoch:92, train acc:0.3233333333333333, test acc:0.2575 ===
# train loss:2.0799579612540744
# train loss:2.139743304558658
# train loss:2.04239430230726
# === epoch:93, train acc:0.32, test acc:0.2587 ===
# train loss:2.1062558687305697
# train loss:2.0627587151547773
# train loss:2.172482029067681
# === epoch:94, train acc:0.32, test acc:0.2596 ===
# train loss:2.1347080467615624
# train loss:2.0455556058020945
# train loss:2.073733073094571
# === epoch:95, train acc:0.32, test acc:0.2595 ===
# train loss:2.0643237116645174
# train loss:2.091176250010941
# train loss:2.1257851108929198
# === epoch:96, train acc:0.3233333333333333, test acc:0.2589 ===
# train loss:2.058678501853801
# train loss:2.0984785895940563
# train loss:2.0802262588359173
# === epoch:97, train acc:0.3233333333333333, test acc:0.262 ===
# train loss:2.0771733158147425
# train loss:2.081173344471379
# train loss:2.0908756041371994
# === epoch:98, train acc:0.32666666666666666, test acc:0.2628 ===
# train loss:2.062864503204253
# train loss:2.033941936374728
# train loss:2.068441848444765
# === epoch:99, train acc:0.33, test acc:0.2629 ===
# train loss:2.035226707339738
# train loss:2.094444028227486
# train loss:2.076890716848085
# === epoch:100, train acc:0.33, test acc:0.2638 ===
# train loss:2.1089354437113683
# train loss:2.048811035831225
# train loss:2.0826164367671023
# === epoch:101, train acc:0.34, test acc:0.2656 ===
# train loss:2.113142615211526
# train loss:2.025387284206415
# train loss:2.083453516117875
# === epoch:102, train acc:0.3433333333333333, test acc:0.2671 ===
# train loss:2.12730622702384
# train loss:2.0660190528869373
# train loss:2.067704925791063
# === epoch:103, train acc:0.3466666666666667, test acc:0.2684 ===
# train loss:2.0489827496813358
# train loss:2.0326466616918095
# train loss:2.109287736364495
# === epoch:104, train acc:0.3566666666666667, test acc:0.2713 ===
# train loss:2.0675041767488382
# train loss:2.0940382502216313
# train loss:2.0502429153443966
# === epoch:105, train acc:0.36, test acc:0.2748 ===
# train loss:2.0592215624684913
# train loss:2.11074719807325
# train loss:2.116276256903847
# === epoch:106, train acc:0.37333333333333335, test acc:0.2789 ===
# train loss:2.0768930333040636
# train loss:2.105281995848987
# train loss:2.030909978915833
# === epoch:107, train acc:0.37333333333333335, test acc:0.28 ===
# train loss:2.0904992206970086
# train loss:2.0429697416853476
# train loss:2.042525595247337
# === epoch:108, train acc:0.37666666666666665, test acc:0.2791 ===
# train loss:2.045789665527598
# train loss:2.0869017929859104
# train loss:2.1281646183554206
# === epoch:109, train acc:0.37666666666666665, test acc:0.2846 ===
# train loss:2.0631565118232125
# train loss:2.077628828464893
# train loss:2.1028315179912536
# === epoch:110, train acc:0.38666666666666666, test acc:0.2892 ===
# train loss:2.0232464120090814
# train loss:2.0854358516052542
# train loss:2.0754209308167004
# === epoch:111, train acc:0.38333333333333336, test acc:0.2884 ===
# train loss:2.0321350032392327
# train loss:2.019408486905964
# train loss:1.9632416419758167
# === epoch:112, train acc:0.38666666666666666, test acc:0.2859 ===
# train loss:1.9463266741202374
# train loss:2.003447262970511
# train loss:2.158320679932406
# === epoch:113, train acc:0.38333333333333336, test acc:0.2893 ===
# train loss:2.091606249153131
# train loss:2.0576641627277112
# train loss:2.072771302947695
# === epoch:114, train acc:0.39, test acc:0.2939 ===
# train loss:2.0727645576908005
# train loss:2.095897663123809
# train loss:2.0085630225882154
# === epoch:115, train acc:0.39, test acc:0.2976 ===
# train loss:2.040154404026926
# train loss:1.9843500360092903
# train loss:2.0608964813066457
# === epoch:116, train acc:0.39, test acc:0.2989 ===
# train loss:2.0477266909085854
# train loss:2.0816203040544745
# train loss:2.0229647265818094
# === epoch:117, train acc:0.39, test acc:0.2994 ===
# train loss:1.9846180316646693
# train loss:2.035319150696627
# train loss:2.0152298428964555
# === epoch:118, train acc:0.39, test acc:0.2972 ===
# train loss:2.0303800811885044
# train loss:2.0058745358733536
# train loss:1.9923614491153692
# === epoch:119, train acc:0.39, test acc:0.2987 ===
# train loss:2.0104168072367035
# train loss:2.1139791307615763
# train loss:2.0453927762748876
# === epoch:120, train acc:0.39, test acc:0.2986 ===
# train loss:1.950027858161264
# train loss:1.9738868433219705
# train loss:2.070620738966851
# === epoch:121, train acc:0.4033333333333333, test acc:0.3057 ===
# train loss:2.097723268844182
# train loss:2.020798734806434
# train loss:2.0265019494374656
# === epoch:122, train acc:0.4066666666666667, test acc:0.3078 ===
# train loss:2.052019405435625
# train loss:2.0176625542980493
# train loss:1.9988746698771245
# === epoch:123, train acc:0.41, test acc:0.3108 ===
# train loss:1.9919545893717356
# train loss:1.968803004077669
# train loss:1.9801593448510975
# === epoch:124, train acc:0.41333333333333333, test acc:0.3098 ===
# train loss:2.036756569834553
# train loss:2.017737366474393
# train loss:1.9382533093019263
# === epoch:125, train acc:0.41333333333333333, test acc:0.313 ===
# train loss:2.0197302427772166
# train loss:2.0691160742061667
# train loss:1.9962940412736883
# === epoch:126, train acc:0.41, test acc:0.312 ===
# train loss:2.010145577463118
# train loss:2.032541176635903
# train loss:2.0375705194824083
# === epoch:127, train acc:0.4266666666666667, test acc:0.3145 ===
# train loss:2.0202363459207104
# train loss:1.9206865664103767
# train loss:2.0189720549879904
# === epoch:128, train acc:0.4266666666666667, test acc:0.3147 ===
# train loss:2.0158789359746607
# train loss:2.0313646253890876
# train loss:2.0129063785621146
# === epoch:129, train acc:0.43333333333333335, test acc:0.3187 ===
# train loss:1.9970021998884342
# train loss:2.0566473169868296
# train loss:1.9685319795763916
# === epoch:130, train acc:0.43, test acc:0.3181 ===
# train loss:1.8916537327786551
# train loss:2.0409367403888727
# train loss:1.9521579306702852
# === epoch:131, train acc:0.42333333333333334, test acc:0.3155 ===
# train loss:1.9825041210866
# train loss:1.926716979933001
# train loss:2.016805979200467
# === epoch:132, train acc:0.4266666666666667, test acc:0.318 ===
# train loss:2.007263052663279
# train loss:1.975550375730149
# train loss:1.9772175453340521
# === epoch:133, train acc:0.42333333333333334, test acc:0.3171 ===
# train loss:1.9698541989791698
# train loss:1.9254285404263871
# train loss:1.9327858543046397
# === epoch:134, train acc:0.42, test acc:0.3181 ===
# train loss:2.003362613967148
# train loss:1.969684103769003
# train loss:1.9442626738502715
# === epoch:135, train acc:0.41333333333333333, test acc:0.3186 ===
# train loss:1.8885605265922687
# train loss:1.9016271380778418
# train loss:2.0696625122576062
# === epoch:136, train acc:0.41333333333333333, test acc:0.3185 ===
# train loss:1.9298276762600883
# train loss:1.938505556404557
# train loss:2.1050749624563427
# === epoch:137, train acc:0.42333333333333334, test acc:0.3213 ===
# train loss:1.9593208302981335
# train loss:1.9818081413919684
# train loss:1.845264208582915
# === epoch:138, train acc:0.4166666666666667, test acc:0.3209 ===
# train loss:1.8481320215137131
# train loss:1.882967559346486
# train loss:1.8429747932243417
# === epoch:139, train acc:0.41333333333333333, test acc:0.32 ===
# train loss:1.8633425111797859
# train loss:1.9997327325234386
# train loss:1.9477711398243631
# === epoch:140, train acc:0.42, test acc:0.3194 ===
# train loss:1.9720062962855573
# train loss:1.9369294273958533
# train loss:2.001403164855486
# === epoch:141, train acc:0.4266666666666667, test acc:0.3217 ===
# train loss:1.931271385019725
# train loss:2.010482402046286
# train loss:1.96765755905285
# === epoch:142, train acc:0.43, test acc:0.3242 ===
# train loss:1.9770486718048443
# train loss:1.965017732128814
# train loss:2.0557947339965166
# === epoch:143, train acc:0.43, test acc:0.3278 ===
# train loss:1.9080776104290555
# train loss:2.0144971960964564
# train loss:1.9838138956104958
# === epoch:144, train acc:0.43333333333333335, test acc:0.3296 ===
# train loss:1.8593708333399694
# train loss:1.9429059225153833
# train loss:2.032787478551396
# === epoch:145, train acc:0.43, test acc:0.329 ===
# train loss:1.8532974318034985
# train loss:2.0727538824826155
# train loss:1.8734765320112774
# === epoch:146, train acc:0.43, test acc:0.3304 ===
# train loss:1.7943839916270514
# train loss:1.8940406673271903
# train loss:1.8821897680405095
# === epoch:147, train acc:0.43, test acc:0.3296 ===
# train loss:1.8991809415851912
# train loss:2.0231927640826535
# train loss:2.0294477945529716
# === epoch:148, train acc:0.44, test acc:0.3367 ===
# train loss:1.7400931378271607
# train loss:1.9532765828596006
# train loss:1.849629690199821
# === epoch:149, train acc:0.44, test acc:0.3385 ===
# train loss:1.9024876589731758
# train loss:1.9614651600255066
# train loss:1.8342975448470902
# === epoch:150, train acc:0.44, test acc:0.3381 ===
# train loss:1.8878346136026993
# train loss:1.9023670123766545
# train loss:1.9866815261343667
# === epoch:151, train acc:0.44, test acc:0.3388 ===
# train loss:1.9260427699837175
# train loss:2.0400180116779296
# train loss:2.0059313725574395
# === epoch:152, train acc:0.43666666666666665, test acc:0.3406 ===
# train loss:1.85074225254204
# train loss:1.9360978747803705
# train loss:1.968861301939219
# === epoch:153, train acc:0.44, test acc:0.3444 ===
# train loss:1.9436969779802293
# train loss:1.9894774210115742
# train loss:1.8977684001394959
# === epoch:154, train acc:0.4533333333333333, test acc:0.3461 ===
# train loss:1.9210810240422989
# train loss:1.9788021208345565
# train loss:1.9214521162335776
# === epoch:155, train acc:0.4533333333333333, test acc:0.3459 ===
# train loss:1.8900967454036524
# train loss:1.9966804483785208
# train loss:1.88959043645917
# === epoch:156, train acc:0.44333333333333336, test acc:0.3459 ===
# train loss:1.9677590996190784
# train loss:1.8847053826603561
# train loss:1.9675328638910559
# === epoch:157, train acc:0.44666666666666666, test acc:0.3454 ===
# train loss:1.8766066912309562
# train loss:1.9151482057672868
# train loss:1.8841488781219211
# === epoch:158, train acc:0.44333333333333336, test acc:0.3439 ===
# train loss:1.9545134170174905
# train loss:1.805798904931705
# train loss:1.9204743989814455
# === epoch:159, train acc:0.44666666666666666, test acc:0.3474 ===
# train loss:1.7925248970341883
# train loss:1.809667395650153
# train loss:1.9611661039524415
# === epoch:160, train acc:0.45666666666666667, test acc:0.3494 ===
# train loss:1.9064383342496134
# train loss:2.003934587321499
# train loss:1.7436643187579788
# === epoch:161, train acc:0.4533333333333333, test acc:0.352 ===
# train loss:1.8897390181038003
# train loss:1.98488148343187
# train loss:1.9278825046186157
# === epoch:162, train acc:0.4533333333333333, test acc:0.3507 ===
# train loss:1.8563924747690412
# train loss:1.8837338620437671
# train loss:1.9366465380538274
# === epoch:163, train acc:0.4533333333333333, test acc:0.3532 ===
# train loss:1.7525041688318863
# train loss:1.8958875955987053
# train loss:1.807543676317755
# === epoch:164, train acc:0.45, test acc:0.3496 ===
# train loss:1.814190656585054
# train loss:1.9453064466297691
# train loss:1.9220622338116826
# === epoch:165, train acc:0.44666666666666666, test acc:0.3506 ===
# train loss:1.7543928260366772
# train loss:1.8177258641071128
# train loss:1.776725316477793
# === epoch:166, train acc:0.45, test acc:0.348 ===
# train loss:1.8796144215226036
# train loss:1.7951059973556602
# train loss:1.841805196482012
# === epoch:167, train acc:0.4533333333333333, test acc:0.348 ===
# train loss:1.8788037708075453
# train loss:1.8160178342230244
# train loss:1.8127433198033387
# === epoch:168, train acc:0.45, test acc:0.3474 ===
# train loss:1.8398688912134566
# train loss:1.8424974117391495
# train loss:1.822278476461543
# === epoch:169, train acc:0.4533333333333333, test acc:0.3477 ===
# train loss:1.812222493253951
# train loss:1.8231731775933826
# train loss:1.9805483316402779
# === epoch:170, train acc:0.45, test acc:0.3471 ===
# train loss:1.8799416446650627
# train loss:1.8313816845925113
# train loss:1.8622721487774905
# === epoch:171, train acc:0.4533333333333333, test acc:0.3494 ===
# train loss:1.8001246931694777
# train loss:1.8119899650260123
# train loss:1.7459267937125882
# === epoch:172, train acc:0.45, test acc:0.3517 ===
# train loss:1.8371492099276225
# train loss:1.8111482214038628
# train loss:1.934661081275561
# === epoch:173, train acc:0.4533333333333333, test acc:0.3528 ===
# train loss:1.894220728894497
# train loss:1.8855714717171719
# train loss:1.7740936381197
# === epoch:174, train acc:0.4633333333333333, test acc:0.3562 ===
# train loss:1.8659973833294712
# train loss:1.8311822599371224
# train loss:1.8118075567700225
# === epoch:175, train acc:0.4533333333333333, test acc:0.3584 ===
# train loss:1.8197890780519872
# train loss:1.8325306978598934
# train loss:1.8683066428920145
# === epoch:176, train acc:0.44666666666666666, test acc:0.3526 ===
# train loss:1.855393812695645
# train loss:1.8382751114317872
# train loss:1.7599826540620034
# === epoch:177, train acc:0.4633333333333333, test acc:0.3579 ===
# train loss:1.9677635637913753
# train loss:1.8800264728837754
# train loss:1.9158973670736652
# === epoch:178, train acc:0.4666666666666667, test acc:0.3637 ===
# train loss:1.8644018939592115
# train loss:1.7217955174613573
# train loss:1.8240356586533932
# === epoch:179, train acc:0.4666666666666667, test acc:0.365 ===
# train loss:1.8163827307406388
# train loss:1.8483977266319696
# train loss:1.8003297502574171
# === epoch:180, train acc:0.4666666666666667, test acc:0.3692 ===
# train loss:1.7546485407068348
# train loss:1.7743836667492243
# train loss:1.7741890643282259
# === epoch:181, train acc:0.4666666666666667, test acc:0.3689 ===
# train loss:1.8032109842138642
# train loss:1.7766663212004723
# train loss:1.864890250273625
# === epoch:182, train acc:0.47333333333333333, test acc:0.3696 ===
# train loss:1.7875840448863385
# train loss:1.8495972234904838
# train loss:1.8238924359285789
# === epoch:183, train acc:0.4766666666666667, test acc:0.3739 ===
# train loss:1.80762529682961
# train loss:1.8044125881723638
# train loss:1.7849642227328233
# === epoch:184, train acc:0.4666666666666667, test acc:0.3749 ===
# train loss:1.8321744861149007
# train loss:1.8823469619856643
# train loss:1.8410869105223673
# === epoch:185, train acc:0.48, test acc:0.3833 ===
# train loss:1.831121405083
# train loss:1.80252021024161
# train loss:1.6832573522128425
# === epoch:186, train acc:0.48, test acc:0.384 ===
# train loss:1.6902609913236777
# train loss:1.5492527313499833
# train loss:1.7874465855687764
# === epoch:187, train acc:0.49333333333333335, test acc:0.3826 ===
# train loss:1.8116398061192556
# train loss:1.7870942177867328
# train loss:1.7601012050693527
# === epoch:188, train acc:0.49, test acc:0.3862 ===
# train loss:1.7110015065314135
# train loss:1.8369907341714145
# train loss:1.7219212619649331
# === epoch:189, train acc:0.4766666666666667, test acc:0.384 ===
# train loss:1.8247358579467094
# train loss:1.7794057183802559
# train loss:1.8027299781391348
# === epoch:190, train acc:0.48, test acc:0.3858 ===
# train loss:1.7988032604168729
# train loss:1.7972610833120692
# train loss:1.772295945297486
# === epoch:191, train acc:0.49333333333333335, test acc:0.3926 ===
# train loss:1.767497951506988
# train loss:1.7497388896799868
# train loss:1.7436090699165672
# === epoch:192, train acc:0.5, test acc:0.3918 ===
# train loss:1.7948723766769026
# train loss:1.7398020072476041
# train loss:1.775456167108828
# === epoch:193, train acc:0.5, test acc:0.3931 ===
# train loss:1.774055174203898
# train loss:1.7603845769645685
# train loss:1.729107204995076
# === epoch:194, train acc:0.5033333333333333, test acc:0.3924 ===
# train loss:1.6908561593390055
# train loss:1.779094870041664
# train loss:1.752444013422088
# === epoch:195, train acc:0.5033333333333333, test acc:0.3949 ===
# train loss:1.6663268856643145
# train loss:1.7573310092336984
# train loss:1.7714042198949858
# === epoch:196, train acc:0.5066666666666667, test acc:0.3948 ===
# train loss:1.6415771542550215
# train loss:1.689008748543454
# train loss:1.652468341701627
# === epoch:197, train acc:0.5033333333333333, test acc:0.4023 ===
# train loss:1.7215383400381117
# train loss:1.7594501211375566
# train loss:1.7344536402510602
# === epoch:198, train acc:0.49666666666666665, test acc:0.4051 ===
# train loss:1.7911988047427605
# train loss:1.64611870888518
# train loss:1.841976243491614
# === epoch:199, train acc:0.5066666666666667, test acc:0.4083 ===
# train loss:1.5740824837759544
# train loss:1.7687514042869008
# train loss:1.6079850599757222
# === epoch:200, train acc:0.5066666666666667, test acc:0.4087 ===
# train loss:1.7489243938950754
# train loss:1.8239938857705698
# train loss:1.6331526950605026
# === epoch:201, train acc:0.51, test acc:0.4146 ===
# train loss:1.7686807110672078
# train loss:1.7453231624585799
# train loss:1.7829582116180893
# === epoch:202, train acc:0.51, test acc:0.4129 ===
# train loss:1.742405091771292
# train loss:1.7124559477826629
# train loss:1.7092519201776937
# === epoch:203, train acc:0.51, test acc:0.4123 ===
# train loss:1.573785587098127
# train loss:1.7293620755400352
# train loss:1.5772887106667626
# === epoch:204, train acc:0.5133333333333333, test acc:0.4131 ===
# train loss:1.7389206803894377
# train loss:1.680563472202251
# train loss:1.7602297901387283
# === epoch:205, train acc:0.5066666666666667, test acc:0.415 ===
# train loss:1.672224030333312
# train loss:1.7381292144843283
# train loss:1.669470690563003
# === epoch:206, train acc:0.5133333333333333, test acc:0.4153 ===
# train loss:1.6994245846863014
# train loss:1.6939326738385683
# train loss:1.7275351052412364
# === epoch:207, train acc:0.5133333333333333, test acc:0.4166 ===
# train loss:1.6535283681132023
# train loss:1.5696838413273246
# train loss:1.798244483203212
# === epoch:208, train acc:0.5166666666666667, test acc:0.4167 ===
# train loss:1.6545352559239657
# train loss:1.6313379712828573
# train loss:1.6653432189497566
# === epoch:209, train acc:0.5233333333333333, test acc:0.4196 ===
# train loss:1.593358282509973
# train loss:1.665397411185143
# train loss:1.6818106269698374
# === epoch:210, train acc:0.5266666666666666, test acc:0.4198 ===
# train loss:1.585161151232658
# train loss:1.7953882190581396
# train loss:1.733018749286261
# === epoch:211, train acc:0.5266666666666666, test acc:0.4227 ===
# train loss:1.6693722182604391
# train loss:1.7090814934063276
# train loss:1.5595856016302196
# === epoch:212, train acc:0.53, test acc:0.4255 ===
# train loss:1.638912047612882
# train loss:1.7287537863281748
# train loss:1.6301473094006251
# === epoch:213, train acc:0.53, test acc:0.4226 ===
# train loss:1.568653644778677
# train loss:1.5648117008446674
# train loss:1.7209445649236346
# === epoch:214, train acc:0.53, test acc:0.4237 ===
# train loss:1.6806533789609501
# train loss:1.6730777242629449
# train loss:1.7207132952265636
# === epoch:215, train acc:0.54, test acc:0.4291 ===
# train loss:1.6811897951989012
# train loss:1.6471107658496897
# train loss:1.7993290260454262
# === epoch:216, train acc:0.5366666666666666, test acc:0.4312 ===
# train loss:1.5777532160109218
# train loss:1.6200397894845562
# train loss:1.6652185442502592
# === epoch:217, train acc:0.5333333333333333, test acc:0.4293 ===
# train loss:1.7192959374596333
# train loss:1.6866268593508693
# train loss:1.6176873601763475
# === epoch:218, train acc:0.5366666666666666, test acc:0.4319 ===
# train loss:1.5433998903822286
# train loss:1.710155527707344
# train loss:1.7470720555962844
# === epoch:219, train acc:0.5366666666666666, test acc:0.4326 ===
# train loss:1.7127507690964479
# train loss:1.5975838930150266
# train loss:1.6130238602270828
# === epoch:220, train acc:0.5366666666666666, test acc:0.4342 ===
# train loss:1.6706648786252836
# train loss:1.5981501729065266
# train loss:1.6618951308733514
# === epoch:221, train acc:0.5366666666666666, test acc:0.4352 ===
# train loss:1.7134782978966092
# train loss:1.6073278727963665
# train loss:1.5434391144654596
# === epoch:222, train acc:0.5433333333333333, test acc:0.4337 ===
# train loss:1.6201406743150064
# train loss:1.598525423080802
# train loss:1.7629395984868037
# === epoch:223, train acc:0.54, test acc:0.4374 ===
# train loss:1.7207704707413245
# train loss:1.3892735069729938
# train loss:1.6117969810726054
# === epoch:224, train acc:0.5366666666666666, test acc:0.4397 ===
# train loss:1.5941630033845624
# train loss:1.637011313667564
# train loss:1.578411333398571
# === epoch:225, train acc:0.5433333333333333, test acc:0.4382 ===
# train loss:1.6357666997107811
# train loss:1.578013979054918
# train loss:1.5793193977209825
# === epoch:226, train acc:0.5466666666666666, test acc:0.4364 ===
# train loss:1.6510927159775377
# train loss:1.612397008891122
# train loss:1.5152712499114183
# === epoch:227, train acc:0.5466666666666666, test acc:0.4421 ===
# train loss:1.6643251351363855
# train loss:1.5423320578586646
# train loss:1.5356802836014143
# === epoch:228, train acc:0.5466666666666666, test acc:0.442 ===
# train loss:1.5426428648708599
# train loss:1.582931444644415
# train loss:1.4143712444562566
# === epoch:229, train acc:0.54, test acc:0.441 ===
# train loss:1.5522508123398047
# train loss:1.5706191728073664
# train loss:1.6102896358302328
# === epoch:230, train acc:0.54, test acc:0.4426 ===
# train loss:1.5666610907240044
# train loss:1.5192314661305901
# train loss:1.5903492031472168
# === epoch:231, train acc:0.5433333333333333, test acc:0.4459 ===
# train loss:1.470467748875441
# train loss:1.547233937200152
# train loss:1.58069765424167
# === epoch:232, train acc:0.54, test acc:0.4484 ===
# train loss:1.4344992313267781
# train loss:1.546488142026425
# train loss:1.5661319771719748
# === epoch:233, train acc:0.5433333333333333, test acc:0.4495 ===
# train loss:1.5548781667819855
# train loss:1.6305569284507149
# train loss:1.6666749808199806
# === epoch:234, train acc:0.54, test acc:0.4508 ===
# train loss:1.5805161497796971
# train loss:1.6392928495477943
# train loss:1.5659579096027167
# === epoch:235, train acc:0.55, test acc:0.4557 ===
# train loss:1.340384260673651
# train loss:1.4706370851479245
# train loss:1.5159691566361326
# === epoch:236, train acc:0.5466666666666666, test acc:0.4543 ===
# train loss:1.5722004506369518
# train loss:1.4825155139046335
# train loss:1.4775914048126204
# === epoch:237, train acc:0.5466666666666666, test acc:0.4533 ===
# train loss:1.47241299144319
# train loss:1.5418059964386988
# train loss:1.5896525536737973
# === epoch:238, train acc:0.5433333333333333, test acc:0.4569 ===
# train loss:1.6183926185871331
# train loss:1.4404979724995157
# train loss:1.4691975252789007
# === epoch:239, train acc:0.5466666666666666, test acc:0.4561 ===
# train loss:1.433577540864706
# train loss:1.488165813942599
# train loss:1.5125431839273273
# === epoch:240, train acc:0.54, test acc:0.4608 ===
# train loss:1.5153272230189203
# train loss:1.4929493264901126
# train loss:1.5286505484506991
# === epoch:241, train acc:0.5533333333333333, test acc:0.4654 ===
# train loss:1.3812402712371386
# train loss:1.5545159866539981
# train loss:1.5491554377423804
# === epoch:242, train acc:0.5566666666666666, test acc:0.4684 ===
# train loss:1.6754663795455407
# train loss:1.5677881188828053
# train loss:1.5785924584990658
# === epoch:243, train acc:0.56, test acc:0.4706 ===
# train loss:1.4592103723040486
# train loss:1.4760846252737332
# train loss:1.5215873697880071
# === epoch:244, train acc:0.5566666666666666, test acc:0.4718 ===
# train loss:1.491817004282853
# train loss:1.4507094779182323
# train loss:1.5201965394403822
# === epoch:245, train acc:0.5533333333333333, test acc:0.4722 ===
# train loss:1.4383331467432283
# train loss:1.4755809546213612
# train loss:1.5609362982634596
# === epoch:246, train acc:0.5533333333333333, test acc:0.4745 ===
# train loss:1.35741683170938
# train loss:1.546341230466264
# train loss:1.4673016178374767
# === epoch:247, train acc:0.5533333333333333, test acc:0.4716 ===
# train loss:1.42260134139841
# train loss:1.4412582164287395
# train loss:1.414601302652802
# === epoch:248, train acc:0.5533333333333333, test acc:0.4688 ===
# train loss:1.4803562939422428
# train loss:1.438707253180212
# train loss:1.4430748757339154
# === epoch:249, train acc:0.5633333333333334, test acc:0.4751 ===
# train loss:1.4261725053666163
# train loss:1.3907861338689909
# train loss:1.3493227501822673
# === epoch:250, train acc:0.5566666666666666, test acc:0.4771 ===
# train loss:1.4084548318255046
# train loss:1.3854849109632912
# train loss:1.4801372939871171
# === epoch:251, train acc:0.5633333333333334, test acc:0.478 ===
# train loss:1.4657053175068666
# train loss:1.446928732876447
# train loss:1.4804557204553763
# === epoch:252, train acc:0.56, test acc:0.4809 ===
# train loss:1.3025655466208048
# train loss:1.4327783704152208
# train loss:1.4261006428042229
# === epoch:253, train acc:0.5733333333333334, test acc:0.4828 ===
# train loss:1.30564510809241
# train loss:1.4202816578074058
# train loss:1.417703000187358
# === epoch:254, train acc:0.58, test acc:0.4852 ===
# train loss:1.494697389148448
# train loss:1.520804190842729
# train loss:1.303492861586368
# === epoch:255, train acc:0.5733333333333334, test acc:0.4868 ===
# train loss:1.3991863355881369
# train loss:1.4372824775561008
# train loss:1.4550930481387332
# === epoch:256, train acc:0.5766666666666667, test acc:0.4864 ===
# train loss:1.411876231357813
# train loss:1.4388126447640692
# train loss:1.345551810645688
# === epoch:257, train acc:0.58, test acc:0.489 ===
# train loss:1.454725054964125
# train loss:1.3539098713446212
# train loss:1.4171859430120313
# === epoch:258, train acc:0.5933333333333334, test acc:0.4962 ===
# train loss:1.4485696863903101
# train loss:1.422952672356045
# train loss:1.4049638913580689
# === epoch:259, train acc:0.5866666666666667, test acc:0.4957 ===
# train loss:1.3560707447125395
# train loss:1.4293035005412804
# train loss:1.342033973957669
# === epoch:260, train acc:0.5933333333333334, test acc:0.4964 ===
# train loss:1.3424050027477212
# train loss:1.2684312532685227
# train loss:1.3547379852691737
# === epoch:261, train acc:0.5933333333333334, test acc:0.498 ===
# train loss:1.4505206890968947
# train loss:1.2906670554691027
# train loss:1.3159422398834593
# === epoch:262, train acc:0.5933333333333334, test acc:0.4996 ===
# train loss:1.2584365885721227
# train loss:1.3299262658545863
# train loss:1.275283245633091
# === epoch:263, train acc:0.5966666666666667, test acc:0.4997 ===
# train loss:1.3735776800986141
# train loss:1.2877568838879982
# train loss:1.3276095976161688
# === epoch:264, train acc:0.59, test acc:0.5025 ===
# train loss:1.3497166600374424
# train loss:1.2553386724115976
# train loss:1.45508630937362
# === epoch:265, train acc:0.5933333333333334, test acc:0.5024 ===
# train loss:1.4668807744389758
# train loss:1.2270073581746261
# train loss:1.3562817367738997
# === epoch:266, train acc:0.6066666666666667, test acc:0.5045 ===
# train loss:1.3374327391518337
# train loss:1.2526625621736285
# train loss:1.1763990079554119
# === epoch:267, train acc:0.6033333333333334, test acc:0.5053 ===
# train loss:1.3282885404655935
# train loss:1.1800684142746292
# train loss:1.267110513415244
# === epoch:268, train acc:0.5966666666666667, test acc:0.5089 ===
# train loss:1.3953343700165226
# train loss:1.282281460983725
# train loss:1.2644155046899213
# === epoch:269, train acc:0.5933333333333334, test acc:0.5089 ===
# train loss:1.2943712673587384
# train loss:1.3538378605525165
# train loss:1.422785738102165
# === epoch:270, train acc:0.6, test acc:0.513 ===
# train loss:1.1976467353392448
# train loss:1.3682105641393392
# train loss:1.2924686193276815
# === epoch:271, train acc:0.6, test acc:0.5129 ===
# train loss:1.3279087380960704
# train loss:1.2249316560964083
# train loss:1.156265654665015
# === epoch:272, train acc:0.6033333333333334, test acc:0.5126 ===
# train loss:1.1815672681455514
# train loss:1.1368756191622977
# train loss:1.2963016065750363
# === epoch:273, train acc:0.6066666666666667, test acc:0.5131 ===
# train loss:1.2186852907247863
# train loss:1.3730208418085865
# train loss:1.2374861497971021
# === epoch:274, train acc:0.61, test acc:0.5146 ===
# train loss:1.2015990779863897
# train loss:1.2474214950384244
# train loss:1.171221184453376
# === epoch:275, train acc:0.6133333333333333, test acc:0.5152 ===
# train loss:1.332116201406249
# train loss:1.2830363564721472
# train loss:1.338285288621883
# === epoch:276, train acc:0.6266666666666667, test acc:0.5181 ===
# train loss:1.1951139820117964
# train loss:1.1096421115305908
# train loss:1.1726780745721053
# === epoch:277, train acc:0.62, test acc:0.5161 ===
# train loss:1.2517130415185367
# train loss:1.1868557995264981
# train loss:1.183497832043306
# === epoch:278, train acc:0.63, test acc:0.5244 ===
# train loss:1.1605784805454558
# train loss:1.2424177459160313
# train loss:1.2583243365454322
# === epoch:279, train acc:0.6333333333333333, test acc:0.5216 ===
# train loss:1.2456802457867016
# train loss:1.2345152601225642
# train loss:1.1330442780716399
# === epoch:280, train acc:0.6233333333333333, test acc:0.5223 ===
# train loss:1.2867849636843345
# train loss:1.085488850652676
# train loss:1.319676543233814
# === epoch:281, train acc:0.6233333333333333, test acc:0.5185 ===
# train loss:1.2441709453029672
# train loss:1.1550630001284206
# train loss:1.177688457300291
# === epoch:282, train acc:0.63, test acc:0.5245 ===
# train loss:1.2432722357407267
# train loss:1.2064814433550095
# train loss:1.306300777639632
# === epoch:283, train acc:0.6366666666666667, test acc:0.5286 ===
# train loss:1.151438285253813
# train loss:1.209077454439659
# train loss:1.155098041264099
# === epoch:284, train acc:0.6433333333333333, test acc:0.5311 ===
# train loss:1.3465572416832001
# train loss:1.1432640594188797
# train loss:1.107427538893247
# === epoch:285, train acc:0.6466666666666666, test acc:0.536 ===
# train loss:1.1316810001288213
# train loss:1.055534657797346
# train loss:1.2876156099606493
# === epoch:286, train acc:0.6433333333333333, test acc:0.5362 ===
# train loss:1.1939426180977506
# train loss:1.0820564756924353
# train loss:1.1110864154084938
# === epoch:287, train acc:0.6466666666666666, test acc:0.5376 ===
# train loss:1.1814761381949532
# train loss:1.1083361107626386
# train loss:0.992606165068954
# === epoch:288, train acc:0.65, test acc:0.5376 ===
# train loss:1.2377716917759376
# train loss:1.1120758732148992
# train loss:1.2558033166905263
# === epoch:289, train acc:0.65, test acc:0.5391 ===
# train loss:1.1097701501519657
# train loss:1.238360042845477
# train loss:1.1031427939065668
# === epoch:290, train acc:0.65, test acc:0.5374 ===
# train loss:1.0537415206904606
# train loss:1.1247110226249517
# train loss:1.0928123911109116
# === epoch:291, train acc:0.6533333333333333, test acc:0.5392 ===
# train loss:1.1029170220113234
# train loss:1.152304521781078
# train loss:1.16897776641543
# === epoch:292, train acc:0.6533333333333333, test acc:0.54 ===
# train loss:1.1458127404854923
# train loss:1.2642694980553377
# train loss:1.013424777108943
# === epoch:293, train acc:0.6533333333333333, test acc:0.5413 ===
# train loss:1.1662482491610149
# train loss:1.160663876852459
# train loss:1.1493056864422666
# === epoch:294, train acc:0.6633333333333333, test acc:0.5431 ===
# train loss:1.0506969278936378
# train loss:1.024480853331778
# train loss:0.9927056529186835
# === epoch:295, train acc:0.6666666666666666, test acc:0.5441 ===
# train loss:1.0584556797979883
# train loss:1.0600067078868043
# train loss:1.1772444541167446
# === epoch:296, train acc:0.6633333333333333, test acc:0.5452 ===
# train loss:1.0334533106585926
# train loss:1.1598951621834954
# train loss:1.1013623136561141
# === epoch:297, train acc:0.67, test acc:0.5451 ===
# train loss:1.1641306884915046
# train loss:1.1764959153889958
# train loss:1.1099505544443655
# === epoch:298, train acc:0.6633333333333333, test acc:0.55 ===
# train loss:1.007428790657022
# train loss:1.1056773332527023
# train loss:1.0873892506829408
# === epoch:299, train acc:0.6666666666666666, test acc:0.5511 ===
# train loss:1.1329221283917923
# train loss:1.0206468576899166
# train loss:0.8688567688211287
# === epoch:300, train acc:0.6633333333333333, test acc:0.5493 ===
# train loss:0.9895037198161272
# train loss:1.1531617101342742
# train loss:1.110575554049572
# === epoch:301, train acc:0.6633333333333333, test acc:0.5504 ===
# train loss:1.071218054178003
# train loss:0.9729274031350325
# =============== Final Test Accuracy ===============
# test acc:0.5513

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.util import shuffle_dataset
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

x_train = x_train[:500]
t_train = t_train[:500]

validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)
x_train, t_train = shuffle_dataset(x_train, t_train)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]


def __train(lr, weight_decay, epocs=50):
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                            output_size=10, weight_decay_lambda=weight_decay)
    trainer = Trainer(network, x_train, t_train, x_val, t_val,
                      epochs=epocs, mini_batch_size=100,
                      optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
    trainer.train()

    return trainer.test_acc_list, trainer.train_acc_list


optimization_trial = 100
results_val = {}
results_train = {}

for _ in range(optimization_trial):
    weight_decay = 10 ** np.random.uniform(-8, -4)
    lr = 10 ** np.random.uniform(-6, -2)
    # ================================================

    val_acc_list, train_acc_list = __train(lr, weight_decay)
    print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
    key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
    results_val[key] = val_acc_list
    results_train[key] = train_acc_list

print("=========== Hyper-Parameter Optimization Result ===========")
graph_draw_num = 20
col_num = 5
row_num = int(np.ceil(graph_draw_num / col_num))
i = 0

for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True):
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + key)

    plt.subplot(row_num, col_num, i+1)
    plt.title("Best-" + str(i+1))
    plt.ylim(0.0, 1.0)
    if i % 5: plt.yticks([])
    plt.xticks([])
    x = np.arange(len(val_acc_list))
    plt.plot(x, val_acc_list)
    plt.plot(x, results_train[key], "--")
    i += 1

    if i >= graph_draw_num:
        break

plt.show()
# Out:
# val acc:0.54 | lr:0.0033266292692413204, weight decay:2.0772571217465964e-05
# val acc:0.1 | lr:5.3764200086326485e-06, weight decay:4.905735357374918e-07
# val acc:0.2 | lr:0.0008651360788368689, weight decay:1.259038490040168e-08
# val acc:0.13 | lr:1.766847825646332e-06, weight decay:8.923975470137914e-08
# val acc:0.09 | lr:1.2072844145931396e-05, weight decay:1.1937838151751816e-06
# val acc:0.09 | lr:5.183578210527894e-06, weight decay:3.072383305121686e-06
# val acc:0.1 | lr:4.284381438423081e-05, weight decay:2.0977859895794787e-08
# val acc:0.14 | lr:8.926850104213529e-06, weight decay:5.5674219891769885e-08
# val acc:0.11 | lr:0.0006087349717156228, weight decay:1.235761359119379e-05
# val acc:0.07 | lr:0.0003946675837934154, weight decay:3.8652347425722964e-08
# val acc:0.15 | lr:3.3516110265310116e-05, weight decay:9.205434118956375e-06
# val acc:0.06 | lr:8.939408212507347e-05, weight decay:2.1291938282971572e-08
# val acc:0.09 | lr:1.29749509845067e-05, weight decay:9.482799571714204e-05
# val acc:0.07 | lr:5.737758285783707e-05, weight decay:5.5907835985305085e-06
# val acc:0.11 | lr:0.00012981490821215795, weight decay:9.140463795781945e-08
# val acc:0.21 | lr:1.8591158965854178e-05, weight decay:2.9270051241504532e-05
# val acc:0.2 | lr:0.001376450615584997, weight decay:9.306494332882493e-05
# val acc:0.23 | lr:0.0005356999530208405, weight decay:1.1483018441154172e-05
# val acc:0.1 | lr:0.00017011696095152446, weight decay:9.286097875862683e-08
# val acc:0.12 | lr:4.349496873644227e-05, weight decay:2.1215399280791124e-06
# val acc:0.1 | lr:0.00042634337386870616, weight decay:2.072999362492983e-06
# val acc:0.63 | lr:0.0066523977888859435, weight decay:6.8953223094875575e-06
# val acc:0.12 | lr:1.3001835387276461e-05, weight decay:3.9373827135628426e-05
# val acc:0.21 | lr:0.0011119695726027128, weight decay:8.904274804388143e-08
# val acc:0.09 | lr:4.206901567397129e-06, weight decay:1.7451316229330027e-07
# val acc:0.25 | lr:0.0012505610161374805, weight decay:1.146339817153782e-08
# val acc:0.36 | lr:0.0021332727420863666, weight decay:3.7666810120460604e-07
# val acc:0.09 | lr:6.448161057670026e-05, weight decay:4.405187568539431e-05
# val acc:0.14 | lr:0.000826465589266508, weight decay:8.25335009655165e-06
# val acc:0.11 | lr:0.0003584363478102008, weight decay:1.2529743905629566e-05
# val acc:0.13 | lr:0.0001315268778924817, weight decay:1.1638872419958511e-05
# val acc:0.23 | lr:0.0008037611764329568, weight decay:4.098961042934221e-07
# val acc:0.08 | lr:0.0003152321264879069, weight decay:1.3675688819969308e-06
# val acc:0.48 | lr:0.004073348734104454, weight decay:1.885253382351459e-05
# val acc:0.05 | lr:3.979702394383703e-05, weight decay:4.508250575522515e-05
# val acc:0.07 | lr:3.589400439769398e-06, weight decay:4.477565220691369e-06
# val acc:0.06 | lr:1.5411687942282843e-06, weight decay:5.3253690034134245e-08
# val acc:0.62 | lr:0.004436508577201174, weight decay:1.6141722512989732e-06
# val acc:0.22 | lr:0.0003779199007996777, weight decay:2.4452625331683898e-06
# val acc:0.1 | lr:5.837620397208614e-06, weight decay:1.6881359303276686e-06
# val acc:0.7 | lr:0.007022690150525322, weight decay:7.376532613825691e-05
# val acc:0.37 | lr:0.0017776640272085407, weight decay:1.3526520772448623e-05
# val acc:0.09 | lr:9.606740934149547e-06, weight decay:5.8472948799878215e-05
# val acc:0.52 | lr:0.0030949948486107314, weight decay:2.359807780791464e-06
# val acc:0.6 | lr:0.005644515863068483, weight decay:1.0123792634265239e-08
# val acc:0.14 | lr:0.00013643351711197175, weight decay:5.61175195653137e-05
# val acc:0.05 | lr:4.3070852177732615e-05, weight decay:5.19414956052777e-07
# val acc:0.15 | lr:1.645905506070314e-06, weight decay:1.604109914018854e-08
# val acc:0.59 | lr:0.005824286801229588, weight decay:3.476689636587487e-07
# val acc:0.08 | lr:3.3038091387564105e-06, weight decay:5.6694120826941815e-06
# val acc:0.07 | lr:6.780263363625539e-05, weight decay:1.375880062368642e-07
# val acc:0.06 | lr:0.0001367446062494112, weight decay:6.118861263554705e-05
# val acc:0.07 | lr:1.222603928937147e-06, weight decay:3.7225742307995674e-08
# val acc:0.13 | lr:2.899764383906391e-05, weight decay:1.1501899098403226e-05
# val acc:0.42 | lr:0.0017289328260731256, weight decay:9.058826282759921e-05
# val acc:0.35 | lr:0.0020282070455103066, weight decay:5.872407138452211e-06
# val acc:0.05 | lr:1.3799463377155175e-06, weight decay:1.519693944398714e-07
# val acc:0.11 | lr:0.00012341928357313515, weight decay:1.025407086554115e-05
# val acc:0.56 | lr:0.004959953794837574, weight decay:3.995054771565722e-05
# val acc:0.11 | lr:0.0006435417425403636, weight decay:3.126515723837623e-05
# val acc:0.29 | lr:0.0014231264916007872, weight decay:2.9679149868079398e-06
# val acc:0.11 | lr:2.0594633180805737e-06, weight decay:3.567768373543934e-06
# val acc:0.16 | lr:1.0538165305202886e-05, weight decay:5.227913796420722e-07
# val acc:0.06 | lr:0.0002370590564387451, weight decay:1.6148528470271433e-07
# val acc:0.14 | lr:4.469579540821426e-06, weight decay:2.0653376140797457e-08
# val acc:0.23 | lr:0.0010681903903193484, weight decay:4.798481623753321e-06
# val acc:0.29 | lr:0.001995982713995329, weight decay:5.745748588639592e-05
# val acc:0.55 | lr:0.003991466373169043, weight decay:6.580888479760923e-05
# val acc:0.1 | lr:5.746907669257794e-06, weight decay:3.5650772088254996e-06
# val acc:0.12 | lr:3.6604855604547293e-06, weight decay:4.1328845414329237e-07
# val acc:0.06 | lr:5.712650628918176e-06, weight decay:1.648950456895698e-05
# val acc:0.13 | lr:0.0006145025527949094, weight decay:9.34207406267625e-05
# val acc:0.63 | lr:0.005351857423566741, weight decay:1.0121124278114518e-08
# val acc:0.16 | lr:6.82958589346674e-05, weight decay:2.746197337165496e-08
# val acc:0.15 | lr:8.74907855749819e-05, weight decay:4.712215206714528e-05
# val acc:0.15 | lr:0.0011914017328211685, weight decay:2.241948899692992e-07
# val acc:0.07 | lr:1.3840890781938856e-06, weight decay:5.692454016313603e-05
# val acc:0.07 | lr:0.00016779840223481532, weight decay:7.568916109798572e-08
# val acc:0.13 | lr:2.0766188934763993e-05, weight decay:1.8300099193882957e-06
# val acc:0.23 | lr:0.0005601483112751318, weight decay:7.09933795541813e-06
# val acc:0.08 | lr:5.4161197265298186e-06, weight decay:3.695265396409566e-06
# val acc:0.12 | lr:0.0001213521151503974, weight decay:3.379128554705845e-07
# val acc:0.07 | lr:3.2860912249476636e-05, weight decay:3.13496271765701e-07
# val acc:0.1 | lr:1.5870002188666644e-06, weight decay:7.074850011063431e-08
# val acc:0.69 | lr:0.006542372664700546, weight decay:3.003207680545096e-08
# val acc:0.28 | lr:0.00048436986158443147, weight decay:9.211622104557628e-05
# val acc:0.1 | lr:0.00018511733061764846, weight decay:2.1347357690732284e-07
# val acc:0.06 | lr:2.954815810846845e-05, weight decay:1.8911692822853303e-07
# val acc:0.12 | lr:6.372054808398691e-06, weight decay:1.9182741573656403e-08
# val acc:0.78 | lr:0.008578068694277761, weight decay:7.748228568576631e-07
# val acc:0.07 | lr:0.0001167156126084128, weight decay:9.099325242832194e-06
# val acc:0.06 | lr:2.604529507991372e-06, weight decay:5.144179149266886e-05
# val acc:0.1 | lr:6.740784854593026e-05, weight decay:8.347259851829682e-05
# val acc:0.48 | lr:0.002309264779328091, weight decay:9.233560365879925e-05
# val acc:0.1 | lr:2.1762396610661967e-06, weight decay:4.2324370401309715e-07
# val acc:0.09 | lr:1.7200362274915048e-05, weight decay:3.180420761344509e-06
# val acc:0.58 | lr:0.004012992921253971, weight decay:2.2728097173714184e-07
# val acc:0.12 | lr:0.0001032459630466116, weight decay:5.371679043449433e-07
# val acc:0.12 | lr:1.2582355527276975e-06, weight decay:1.1519028513494025e-07
# val acc:0.26 | lr:0.0008131574016072541, weight decay:1.061427799712781e-08
# =========== Hyper-Parameter Optimization Result ===========
# Best-1(val acc:0.78) | lr:0.008578068694277761, weight decay:7.748228568576631e-07
# Best-2(val acc:0.7) | lr:0.007022690150525322, weight decay:7.376532613825691e-05
# Best-3(val acc:0.69) | lr:0.006542372664700546, weight decay:3.003207680545096e-08
# Best-4(val acc:0.63) | lr:0.0066523977888859435, weight decay:6.8953223094875575e-06
# Best-5(val acc:0.63) | lr:0.005351857423566741, weight decay:1.0121124278114518e-08
# Best-6(val acc:0.62) | lr:0.004436508577201174, weight decay:1.6141722512989732e-06
# Best-7(val acc:0.6) | lr:0.005644515863068483, weight decay:1.0123792634265239e-08
# Best-8(val acc:0.59) | lr:0.005824286801229588, weight decay:3.476689636587487e-07
# Best-9(val acc:0.58) | lr:0.004012992921253971, weight decay:2.2728097173714184e-07
# Best-10(val acc:0.56) | lr:0.004959953794837574, weight decay:3.995054771565722e-05
# Best-11(val acc:0.55) | lr:0.003991466373169043, weight decay:6.580888479760923e-05
# Best-12(val acc:0.54) | lr:0.0033266292692413204, weight decay:2.0772571217465964e-05
# Best-13(val acc:0.52) | lr:0.0030949948486107314, weight decay:2.359807780791464e-06
# Best-14(val acc:0.48) | lr:0.004073348734104454, weight decay:1.885253382351459e-05
# Best-15(val acc:0.48) | lr:0.002309264779328091, weight decay:9.233560365879925e-05
# Best-16(val acc:0.42) | lr:0.0017289328260731256, weight decay:9.058826282759921e-05
# Best-17(val acc:0.37) | lr:0.0017776640272085407, weight decay:1.3526520772448623e-05
# Best-18(val acc:0.36) | lr:0.0021332727420863666, weight decay:3.7666810120460604e-07
# Best-19(val acc:0.35) | lr:0.0020282070455103066, weight decay:5.872407138452211e-06
# Best-20(val acc:0.29) | lr:0.0014231264916007872, weight decay:2.9679149868079398e-06
